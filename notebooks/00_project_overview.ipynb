# %% [markdown]
# # US Housing Price Prediction - Project Overview
#
# This notebook is the entry point for the modular notebook workflow. The project was completed for Singapore Polytechnic, School of Computing, Diploma in Applied AI & Analytics, under AI & Machine Learning (`ST1511`) CA1 Part B.
#
# Student: Goh Kun Ming
# Academic year: AY24/25, Year 1 Semester 2
# Lecturer: Adjunct Lecturer Tai Hock Lin (Andy)

# %% [markdown]
# ## Notebook Workflow
#
# Run the notebooks in this order when you want the complete narrative workflow:
#
# 1. `01_data_validation_and_eda.ipynb`
# 2. `02_feature_engineering.ipynb`
# 3. `03_model_training_and_evaluation.ipynb`
# 4. `04_prediction_demo.ipynb`
#
# The production code lives in `src/us_housing_price_prediction`, so notebooks stay small and focused instead of holding reusable logic.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

src_path = PROJECT_ROOT / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from us_housing_price_prediction.config import DEFAULT_DATA_PATH

print(f"Dataset: {DEFAULT_DATA_PATH}")
print("Use the numbered notebooks for the full workflow.")
